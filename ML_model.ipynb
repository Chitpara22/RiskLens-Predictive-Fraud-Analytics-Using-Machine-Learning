# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

from imblearn.over_sampling import SMOTE

# %%
import pandas as pd

# %%
df = pd.read_csv("financial performance factor analysis in businesses systems.csv")

print(df.shape)
df.head()
# Out:
# (5332, 30)
#          Date Customer_ID  Gender  Age  Region Acquisition_Channel  \
# 0  01-01-2023  CUST108549    Male   45     Uae               Email
# 1  01-01-2023  CUST100742  Female   40   India               Email
# 2  01-01-2023  CUST102330    Male   31     Usa             Organic
# 3  01-01-2023  CUST100558  Female   36  Canada            Referral
# 4  01-01-2023  CUST107249    Male   35   India        Social Media
#
#   Lead_Source Device_Type Product_Plan Subscription_Type  ...  \
# 0         App      Tablet        Basic           Monthly  ...
# 1         App         Web     Standard           Monthly  ...
# 2         App      Mobile        Basic           Monthly  ...
# 3         App      Tablet      Premium           Monthly  ...
# 4     Partner      Tablet     Standard           Monthly  ...
#
#    Customer_Satisfaction_Score  Employees_Count  year  month  quarter  \
# 0                          4.8              162  2023      1        1
# 1                          4.8              246  2023      1        1
# 2                          3.9              107  2023      1        1
# 3                          4.6               81  2023      1        1
# 4                          3.9              189  2023      1        1
#
#    Total_Cost   Profit Profit_Margin_% Effective_Revenue  Is_fraud
# 0     7898.27  7596.76       49.027075          15495.03       1.0
# 1     4220.42  3348.70       44.241603           7569.12       0.0
# 2     5175.45  1874.10       26.584676           7049.55       0.0
# 3     6384.54  5618.89       46.810703          12003.43       1.0
# 4     8813.50 -3443.32      -64.119266           5370.18       0.0
#
# [5 rows x 30 columns]

# %%
# remove useless IDs (avoid leakage)
df.drop(columns=['Unnamed: 0','trans_num','cc_num'],
        errors='ignore', inplace=True)

# %%
if 'trans_date_trans_time' in df.columns:
    df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

    df['hour'] = df['trans_date_trans_time'].dt.hour
    df['day'] = df['trans_date_trans_time'].dt.day
    df['month'] = df['trans_date_trans_time'].dt.month

    df.drop('trans_date_trans_time', axis=1, inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

df.fillna(df.median(numeric_only=True), inplace=True)

# %%
X = df.drop("Is_fraud", axis=1)
y = df["Is_fraud"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=42
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
smote = SMOTE(sampling_strategy=0.3, random_state=42)

X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

print("After SMOTE:")
print(np.bincount(y_train_bal))
# Out:
# After SMOTE:
# [3356 1006]

# %%
model = RandomForestClassifier(
    n_estimators=80,
    max_depth=8,
    min_samples_split=20,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

model.fit(X_train_bal, y_train_bal)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=8,
#                        min_samples_split=20, n_estimators=80, n_jobs=-1,
#                        random_state=42)

# %%
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:,1]

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# Accuracy: 0.8237059264816204
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.90      1119
#          1.0       0.45      0.40      0.42       214
#
#     accuracy                           0.82      1333
#    macro avg       0.67      0.65      0.66      1333
# weighted avg       0.82      0.82      0.82      1333
#
#
# ROC-AUC: 0.7524784311760334

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#user input

amt = float(input("Enter transaction amount: "))
hour = int(input("Enter hour (0-23): "))
input_data = pd.DataFrame([{
    'amt': amt,
    'hour': hour,
    'day': 1,
    'month': 1
}])
input_data = input_data.reindex(columns=X.columns, fill_value=0)
input_scaled = scaler.transform(input_data)
pred = rf.predict(input_scaled)
print("Fraud" if pred[0] == 1 else "Not Fraud")
# Out:
# Enter transaction amount:  10000
# Enter hour (0-23):  2
# Not Fraud
